# %%
import pandas as pd

# %%
path = 'C:/Users/jjoao/AnaliseDeDados/'

# %%
tb_diabetes = pd.read_excel(path+'diabetes.xlsx', 'in')
tb_diabetes.head()
# Out:
#    pressao arterial  concentraçao de glicose  insulina tipo sanguineo  idade  \
# 0              72.0                    148.0       NaN              A     50
# 1              66.0                     85.0       NaN              O     31
# 2              64.0                    183.0       NaN              A     32
# 3              66.0                     89.0      94.0              A     21
# 4              40.0                    137.0     168.0              O     33
#
#     imc diabetico
# 0  33.6         S
# 1  26.6         N
# 2  23.3         S
# 3  28.1         N
# 4  43.1         S

# %%
tb_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   pressao arterial         733 non-null    float64
#  1   concentraçao de glicose  763 non-null    float64
#  2   insulina                 394 non-null    float64
#  3   tipo sanguineo           723 non-null    object
#  4   idade                    768 non-null    int64
#  5   imc                      757 non-null    float64
#  6   diabetico                768 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 42.1+ KB

# %%
tb_diabetes.isna().sum()
# Out:
# pressao arterial            35
# concentraçao de glicose      5
# insulina                   374
# tipo sanguineo              45
# idade                        0
# imc                         11
# diabetico                    0
# dtype: int64

# %%
tb_diabetes['diabetico'].value_counts()
# Out:
# diabetico
# N    500
# S    268
# Name: count, dtype: int64

# %%
tb_diabetes[tb_diabetes['concentraçao de glicose'].isna() | tb_diabetes['imc'].isna()]
# Out:
#      pressao arterial  concentraçao de glicose  insulina tipo sanguineo  \
# 9                96.0                    125.0       NaN              A
# 49                NaN                    105.0       NaN              A
# 60                NaN                     84.0       NaN            NaN
# 75               48.0                      NaN       NaN              A
# 81                NaN                     74.0       NaN              A
# 145              75.0                    102.0       NaN              A
# 182              74.0                      NaN      23.0              O
# 342              68.0                      NaN       NaN              A
# 349              80.0                      NaN       NaN              O
# 371              64.0                    118.0      89.0              O
# 426               NaN                     94.0       NaN              B
# 494               NaN                     80.0       NaN              B
# ...

# %%
tb_diabetes.dropna(axis='index', subset=['concentraçao de glicose', 'imc'], inplace = True)

# %%
tb_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 752 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   pressao arterial         724 non-null    float64
#  1   concentraçao de glicose  752 non-null    float64
#  2   insulina                 392 non-null    float64
#  3   tipo sanguineo           709 non-null    object
#  4   idade                    752 non-null    int64
#  5   imc                      752 non-null    float64
#  6   diabetico                752 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 47.0+ KB

# %%
tb_diabetes.isna().sum()
# Out:
# pressao arterial            28
# concentraçao de glicose      0
# insulina                   360
# tipo sanguineo              43
# idade                        0
# imc                          0
# diabetico                    0
# dtype: int64

# %%
tb_diabetes[tb_diabetes['insulina'].isna()].head(10)
# Out:
#     pressao arterial  concentraçao de glicose  insulina tipo sanguineo  idade  \
# 0               72.0                    148.0       NaN              A     50
# 1               66.0                     85.0       NaN              O     31
# 2               64.0                    183.0       NaN              A     32
# 5               74.0                    116.0       NaN              A     30
# 7                NaN                    115.0       NaN              A     29
# 10              92.0                    110.0       NaN              O     30
# 11              74.0                    168.0       NaN            NaN     34
# 12              80.0                    139.0       NaN              O     57
# 15               NaN                    100.0       NaN             AB     32
# 17              74.0                    107.0       NaN             AB     31
#
#      imc diabetico
# 0   33.6         S
# 1   26.6         N
# 2   23.3         S
# 5   25.6         N
# ...

# %%
tb_diabetes['leu insulina'] = ~tb_diabetes['insulina'].isna()
tb_diabetes
# Out:
#      pressao arterial  concentraçao de glicose  insulina tipo sanguineo  \
# 0                72.0                    148.0       NaN              A
# 1                66.0                     85.0       NaN              O
# 2                64.0                    183.0       NaN              A
# 3                66.0                     89.0      94.0              A
# 4                40.0                    137.0     168.0              O
# ..                ...                      ...       ...            ...
# 763              76.0                    101.0     180.0              A
# 764              70.0                    122.0       NaN              A
# 765              72.0                    121.0     112.0              O
# 766              60.0                    126.0       NaN            NaN
# 767              70.0                     93.0       NaN              A
#
#      idade   imc diabetico  leu insulina
# 0       50  33.6         S         False
# ...

# %%
tb_diabetes.drop(columns=['insulina'], inplace = True)
tb_diabetes
# Out:
#      pressao arterial  concentraçao de glicose tipo sanguineo  idade   imc  \
# 0                72.0                    148.0              A     50  33.6
# 1                66.0                     85.0              O     31  26.6
# 2                64.0                    183.0              A     32  23.3
# 3                66.0                     89.0              A     21  28.1
# 4                40.0                    137.0              O     33  43.1
# ..                ...                      ...            ...    ...   ...
# 763              76.0                    101.0              A     63  32.9
# 764              70.0                    122.0              A     27  36.8
# 765              72.0                    121.0              O     30  26.2
# 766              60.0                    126.0            NaN     47  30.1
# 767              70.0                     93.0              A     23  30.4
#
#     diabetico  leu insulina
# 0           S         False
# ...

# %%
tb_diabetes.isna().sum()
# Out:
# pressao arterial           28
# concentraçao de glicose     0
# tipo sanguineo             43
# idade                       0
# imc                         0
# diabetico                   0
# leu insulina                0
# dtype: int64

# %%
tb_diabetes['pressao arterial']
# Out:
# 0      72.0
# 1      66.0
# 2      64.0
# 3      66.0
# 4      40.0
#        ...
# 763    76.0
# 764    70.0
# 765    72.0
# 766    60.0
# 767    70.0
# Name: pressao arterial, Length: 752, dtype: float64

# %%
tb_diabetes['tipo sanguineo']
# Out:
# 0        A
# 1        O
# 2        A
# 3        A
# 4        O
#       ...
# 763      A
# 764      A
# 765      O
# 766    NaN
# 767      A
# Name: tipo sanguineo, Length: 752, dtype: object

# %%
tb_diabetes['pressao arterial'].describe()
# Out:
# count    724.000000
# mean      72.400552
# std       12.379870
# min       24.000000
# 25%       64.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: pressao arterial, dtype: float64

# %%
tb_diabetes['tipo sanguineo'].value_counts()
# Out:
# tipo sanguineo
# A     390
# O     223
# B      75
# AB     21
# Name: count, dtype: int64

# %%
tb_diabetes.fillna({'pressao arterial': 72.4, 'tipo sanguineo': 'A'}, inplace = True)

# %%
tb_diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 752 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   pressao arterial         752 non-null    float64
#  1   concentraçao de glicose  752 non-null    float64
#  2   tipo sanguineo           752 non-null    object
#  3   idade                    752 non-null    int64
#  4   imc                      752 non-null    float64
#  5   diabetico                752 non-null    object
#  6   leu insulina             752 non-null    bool
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 41.9+ KB

# %%
tb_diabetes.isna().sum()
# Out:
# pressao arterial           0
# concentraçao de glicose    0
# tipo sanguineo             0
# idade                      0
# imc                        0
# diabetico                  0
# leu insulina               0
# dtype: int64
